# %% [markdown]
# # Reading CSV

# %%
import pandas as pd
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv')

# %%
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv')
df
# Out:
#   stockdata     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0   tickers            eps    revenue      price         people
# 1     GOOGL          27.82         87        845     larry page
# 2       WMT           4.61        484         65           n.a.
# 3      MSFT             -1         85         64     bill gates
# 4      RIL   not available         50       1023  mukesh ambani
# 5      TATA            5.6         -1       n.a.     ratan tata

# %%
# using skip rows
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv',skiprows=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df
# Out:
#   stockdata     Unnamed: 1 Unnamed: 2 Unnamed: 3     Unnamed: 4
# 0   tickers            eps    revenue      price         people
# 1     GOOGL          27.82         87        845     larry page
# 2       WMT           4.61        484         65           n.a.
# 3      MSFT             -1         85         64     bill gates
# 4      RIL   not available         50       1023  mukesh ambani
# 5      TATA            5.6         -1       n.a.     ratan tata

# %%
#by using header function instead of skip rows
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv',header=1)
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#Suppose the csv file doesnot have the header column

# %%
import pandas as pd
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv')
df
# Out:
#   GOOGL          27.82   87   845     larry page
# 0   WMT           4.61  484    65           n.a.
# 1  MSFT             -1   85    64     bill gates
# 2  RIL   not available   50  1023  mukesh ambani
# 3  TATA            5.6   -1  n.a.     ratan tata

# %%
#providing the columns names manually
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv', header=None, names=['ticker','eps','revenue','price','people'])
df
# Out:
#   ticker            eps  revenue price         people
# 0  GOOGL          27.82       87   845     larry page
# 1    WMT           4.61      484    65           n.a.
# 2   MSFT             -1       85    64     bill gates
# 3   RIL   not available       50  1023  mukesh ambani
# 4   TATA            5.6       -1  n.a.     ratan tata

# %%
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
#when you want to read only the 3 rows
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv',nrows=3)
df
# Out:
#   tickers    eps  revenue  price      people
# 0   GOOGL  27.82       87    845  larry page
# 1     WMT   4.61      484     65        n.a.
# 2    MSFT  -1.00       85     64  bill gates

# %%
#when you want to read only the 3 rows
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv',head=3)
df
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 2
#       1 #when you want to read only the 3 rows
# ----> 2 df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv',head=3)
#       3 df
#
# TypeError: read_csv() got an unexpected keyword argument 'head'

# %%
df.head(3)
# Out:
#   tickers    eps  revenue price      people
# 0   GOOGL  27.82     87.0   845  larry page
# 1     WMT   4.61    484.0    65         NaN
# 2    MSFT  -1.00     85.0    64  bill gates

# %%
#Cleaning the messy data replacing the "not available and n.a. values by NaN in python"
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv',na_values=['not available','n.a.'])
df
# Out:
#   tickers    eps  revenue   price         people
# 0   GOOGL  27.82       87   845.0     larry page
# 1     WMT   4.61      484    65.0            NaN
# 2    MSFT  -1.00       85    64.0     bill gates
# 3    RIL     NaN       50  1023.0  mukesh ambani
# 4    TATA   5.60       -1     NaN     ratan tata

# %%
#Cleaing the data column wise 
Suppose you only want remove the -1 form revenue column and don't want to remove -1 from eps then 
at na_values we can provide the dictionary also

# %%
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv')
df
# Out:
#   tickers            eps  revenue price         people
# 0   GOOGL          27.82       87   845     larry page
# 1     WMT           4.61      484    65           n.a.
# 2    MSFT             -1       85    64     bill gates
# 3    RIL   not available       50  1023  mukesh ambani
# 4    TATA            5.6       -1  n.a.     ratan tata

# %%
df =  pd.read_csv('D:/Data_analyst/Python/stock_data.csv',
                  na_values={
                      'revenue' : ['not available','n.a.',-1],
                      'eps' : ['not available','n.a.'],
                        'people' : ['not available','n.a.']
                        }
                    )
df
# Out:
#   tickers    eps  revenue price         people
# 0   GOOGL  27.82     87.0   845     larry page
# 1     WMT   4.61    484.0    65            NaN
# 2    MSFT  -1.00     85.0    64     bill gates
# 3    RIL     NaN     50.0  1023  mukesh ambani
# 4    TATA   5.60      NaN  n.a.     ratan tata

# %% [markdown]
# ### Write CSV files

# %%
df.to_csv('D:/Data_analyst/Python/new.csv',index=False)

# %%
#if you want to only export few columns
df.to_csv('D:/Data_analyst/Python/new_2.csv',index=False,columns=['tickers','eps'])

# %%
#if you want to skip exporting the header
df.to_csv('D:/Data_analyst/Python/new_3.csv',index=False,header=False)
